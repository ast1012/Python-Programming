# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as pt

# %%
data = pd.read_csv(r'C:\Users\astha\Downloads\ViewingActivity-sample.csv')

# %%
df = pd.DataFrame(data)

# %%
print("                            -------**  First five rows of data sheet  **-------  ")
n = int(input("-->"))
df.head(n)
# Out:
#                             -------**  First five rows of data sheet  **-------
# -->3
#   Profile Name        Start Time  Duration  Attributes  \
# 0      Charlie  20-03-2013 05:17  00:00:05         NaN
# 1      Charlie  20-03-2013 04:27  00:44:31         NaN
# 2      Charlie  20-03-2013 04:05  00:22:06         NaN
#
#                         Title                           Video Watched   \
# 0  Star Trek: Deep Space Nine         Season 5: Empok Nor (Episode 24)
# 1  Star Trek: Deep Space Nine    Season 5: Blaze of Glory (Episode 23)
# 2  Star Trek: Deep Space Nine  Season 5: Children of Time (Episode 22)
#
#   Device Type  Bookmark  Latest Bookmark             Country
# 0         Mac  00:00:05  Not latest view  US (United States)
# 1         Mac  00:44:31  Not latest view  US (United States)
# 2         Mac  00:44:37         00:44:37  US (United States)

# %%
print("                           -------**  Last five rows of data sheet  **-------  ")
n = int(input("-->"))
df.tail(n)
# Out:
#                            -------**  Last five rows of data sheet  **-------
# -->3
#     Profile Name        Start Time  Duration  Attributes  \
# 197      Charlie  01-03-2013 23:21  00:21:59         NaN
# 198      Charlie  01-03-2013 22:36  00:44:26         NaN
# 199      Charlie  01-03-2013 20:47  00:43:48         NaN
#
#                           Title                         Video Watched   \
# 197  Star Trek: Deep Space Nine      Season 4: Body Parts (Episode 24)
# 198  Star Trek: Deep Space Nine  Season 4: The Quickening (Episode 23)
# 199  Star Trek: Deep Space Nine    Season 4: To the Death (Episode 22)
#
#     Device Type  Bookmark  Latest Bookmark             Country
# 197         Mac  00:22:01  Not latest view  US (United States)
# 198         Mac  00:44:28         00:44:28  US (United States)
# 199         Mac  00:43:48         00:43:48  US (United States)

# %%
print("Display all the columns")
df.columns
# Out:
# Display all the columns
# Index(['Profile Name', 'Start Time', 'Duration', 'Attributes', 'Title',
#        'Video Watched ', 'Device Type', 'Bookmark', 'Latest Bookmark',
#        'Country'],
#       dtype='object')

# %%
#Data Cleaning

# %%
df.isna()
# Out:
#      Profile Name  Start Time  Duration  Attributes  Title  Video Watched   \
# 0           False       False     False        True  False           False
# 1           False       False     False        True  False           False
# 2           False       False     False        True  False           False
# 3           False       False     False        True  False           False
# 4           False       False     False        True  False           False
# ..            ...         ...       ...         ...    ...             ...
# 195         False       False     False        True  False           False
# 196         False       False     False        True  False           False
# 197         False       False     False        True  False           False
# 198         False       False     False        True  False           False
# 199         False       False     False        True  False           False
#
#      Device Type  Bookmark  Latest Bookmark  Country
# ...

# %%
df.drop(["Attributes"],axis=1)
# Out:
#     Profile Name        Start Time  Duration                       Title  \
# 0        Charlie  20-03-2013 05:17  00:00:05  Star Trek: Deep Space Nine
# 1        Charlie  20-03-2013 04:27  00:44:31  Star Trek: Deep Space Nine
# 2        Charlie  20-03-2013 04:05  00:22:06  Star Trek: Deep Space Nine
# 3        Charlie  20-03-2013 00:20  00:48:14           The Invisible War
# 4        Charlie  20-03-2013 00:10  00:04:51           The Invisible War
# ..           ...               ...       ...                         ...
# 195      Charlie  02-03-2013 00:45  00:05:18  Star Trek: Deep Space Nine
# 196      Charlie  01-03-2013 23:46  00:58:12                Louis C.K.:
# 197      Charlie  01-03-2013 23:21  00:21:59  Star Trek: Deep Space Nine
# 198      Charlie  01-03-2013 22:36  00:44:26  Star Trek: Deep Space Nine
# 199      Charlie  01-03-2013 20:47  00:43:48  Star Trek: Deep Space Nine
#
#                               Video Watched          Device Type  Bookmark  \
# ...

# %%
df.dtypes
# Out:
# Profile Name        object
# Start Time          object
# Duration            object
# Attributes         float64
# Title               object
# Video Watched       object
# Device Type         object
# Bookmark            object
# Latest Bookmark     object
# Country             object
# dtype: object

# %%
df['Start Time']= pd.to_datetime(df['Start Time'], utc = True)
df['Duration'] = pd.to_timedelta(df['Duration'])
df.dtypes
# Out:
# Profile Name                    object
# Start Time         datetime64[ns, UTC]
# Duration               timedelta64[ns]
# Attributes                     float64
# Title                           object
# Video Watched                   object
# Device Type                     object
# Bookmark                        object
# Latest Bookmark                 object
# Country                         object
# dtype: object

# %%
pt.figure(figsize = (15,10))
pt.bar(data["Title"], data["Duration"], color = ["green","red","black", "blue", "yellow"])
pt.title('Daily Data Watching Analysis')
pt.xlabel('Video Watched')
pt.ylabel('Duration')
pt.xticks(rotation=45)
pt.show()

# %%
freq = df.value_counts(["Title"])

# %%
freq
# Out:
# Title
# The Office (U.S.)              100
# Star Trek: Deep Space Nine      43
# The Office                      23
# Archer                           9
# The Office (U.S.)                8
# The Office (U.S.):               4
# Archer:                          3
# The Office (U.S.):               2
# The Invisible War                2
# Archer                           2
# 30 for 30: The Two Escobars      2
# Louis C.K.:                      1
# Buffy the Vampire Slayer         1
# dtype: int64

# %%
pt.figure(figsize = (10,15))
pt.pie(freq)# color = ["red","green","black", "white", "yellow"])
pt.title('Daily Data Watching Analysis')
pt.show()
